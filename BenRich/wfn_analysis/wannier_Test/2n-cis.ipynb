# %%
import numpy as np
data_dir = "D://scratch_backup//perl//wannier_test//PtPyrOpt//2n-cis//No_bias//"
from scipy.interpolate import interp1d
import sys
sys.path.append("C://Users//User//PycharmProjects//Musgrave_scripts//BenRich//common_funcs")
import cohpfuncs as cfunc
import jdftxfuncs as jfunc
import matplotlib.pyplot as plt

# %%
fname = data_dir + 'wannier.out'
S, R = jfunc.SR_wannier_out(fname)

# %%
wrange = [0, 1, 2, 3, 4, 5]
wanniers = []
for w in wrange:
    wanniers.append(np.fromfile(data_dir + 'wannier.' + str(w) + '.mlwfUp').reshape(S[0], S[1], S[2]))
# wannier0 = np.fromfile(data_dir + 'wannier.0.mlwfUp')
# wannier0 = wannier0.reshape(S[0], S[1], S[2])
# wannier1 = np.fromfile(data_dir + 'wannier.1.mlwfUp')
# wannier1 = wannier1.reshape(S[0], S[1], S[2])

# %%
fig, axes = plt.subplots(nrows=1, ncols=len(wrange), figsize=(10, 5))
for w in wrange:
    axes[w].imshow(wanniers[w].sum(axis=2))
fig.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_15828\1939244001.py:4: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
plt.imshow(wannier0.sum(axis=2))

# %%
wannier0
# Out:
# array([[[nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         ...,
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan]],
#
#        [[nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         ...,
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan]],
#
#        [[nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         ...,
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan]],
#
#        ...,
#
#        [[nan, nan, nan, ..., nan, nan, nan],
# ...

# %%
R, S = SR_wannier_out(data_dir + 'wannier.out')

# %%
S
# Out:
# [96, 96, 90]
