# %%
import collect

# %%
start_dir = '/Users/richb/Desktop/Research/Musgrave/mncs/Aziz Structures'
data = collect.look_for_ecomp(start_dir)

# %%
collect.plot_etype_wrt_V(data['MN4C']['pyridinic']['surfs']['Pt'], 'Etot')

# %%
collect.plot_etype_wrt_V(data['MN3C']['pyridinic']['surfs']['Pt'], 'Etot')

# %%
collect.plot_etype_wrt_V(data['MN2trC']['pyridinic']['surfs']['Pt'], 'Etot')
