# %%
import json
from funcs import plot_adsorption
import matplotlib.pyplot as plt
import numpy as np
data_path = 'D://scratch_backup//alpine//beri9208//mnc-pt-pyrid//results//all_data.json'
savedir = 'C://Users//Users//PycharmProjects//Musgrave_scripts//BenRich//json_plots//mnc-pt-pyrid-plots//'

# %%
surf_name = '1n'
label_strs = ['Pt', 'N', 'tC', 'cC', 'Pt-N', 'Pt-cC', 'N-cC', 'tC-cC']
plot_adsorption(surf_name, label_strs, data_path, savedir)

# %%
surf_name = '2n-trans'
label_strs = ['Pt', 'N', 'C1', 'Pt-N', 'Pt-C', 'N-C']
plot_adsorption(surf_name, label_strs, data_path, savedir)

# %%
surf_name = '2n-cis'
label_strs = ['Pt', 'N', 'C1', 'Pt-N', 'Pt-C', 'N-N', 'N-C', 'C-C']
plot_adsorption(surf_name, label_strs, data_path, savedir)

# %%
surf_name = '3n'
label_strs = ['Pt', 'tN', 'cN', 'C', 'Pt-tN', 'Pt-cN', 'Pt-C', 'tN-cN', 'cN-C']
plot_adsorption(surf_name, label_strs, data_path, savedir)

# %%
surf_name = '4n'
label_strs = ['Pt', 'N', 'Pt-N', 'N-N']
plot_adsorption(surf_name, label_strs, data_path, savedir)
